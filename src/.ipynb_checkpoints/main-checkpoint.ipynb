# %%
DATA_TRAIN_PROCESSED = '../data/prepocessed/train.csv'

# %%
import pipeline
pipeline.run()
# Out:
# Nhập đường dẫn data train:
# ../data/prepocessed/train.csv
# Data train có dạng:
#          Date  temperatures
# 0  1981-01-01          20.7
# 1  1981-01-02          17.9
# 2  1981-01-03          18.8
# 3  1981-01-04          14.6
# 4  1981-01-05          15.8
# Cỡ: (2920, 2)
#
# #-----------------------------------DATA PROCESSING------------------------#
# #----------Phát hiện bất thường-----------#
# 0. Đóng chương trình
# 1. Không dùng
# 2. Boxplot
# 3. Rolling window
# 2
# Điều chỉnh mức độ nhạy (Hệ số nhân với IQR):
# 1. 1.5 (phổ biến, mặc định)
# 2. 1.0 (nhạy cảm)
# 3. 3.0 (ít nhạy))
# 1
# Phát hiện 22 outliers.
# #----------Thay thế outliers và điền giá trị thiếu-----------#
# Lựa chọn phương pháp điền giá trị thiếu:
# 1. mean
# 2. backward
# 3. forward
# 4. interpolate(mặc định)
# 4
# Chọn mặc định fill: interpolate
# Thay thế 22 outliers và fill: '4'.
# #--------------Chuẩn hóa dữ liệu------------#
# Lựa chọn phương pháp chuẩn hóa:
# 1. Standard
# 2. Minmax
# 3. Robust
# ...
